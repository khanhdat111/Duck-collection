# %%
import glob

import numpy as np
from PIL import Image
from skimage.io import imread
from tqdm import tqdm

folder_path = "/kaggle/input/cvc-clinic-png/"  # Add the path to your data directory


def load_data(img_height, img_width, images_to_be_loaded, dataset):
    IMAGES_PATH = folder_path + 'Original/'
    MASKS_PATH = folder_path + 'Ground Truth/'

    if dataset == 'kvasir':
        train_ids = glob.glob(IMAGES_PATH + "*.jpg")

    if dataset == 'cvc-clinicdb':
        train_ids = glob.glob(IMAGES_PATH + "*.png")
        #train_ids = train_ids[:30]

    if dataset == 'cvc-colondb' or dataset == 'etis-laribpolypdb':
        train_ids = glob.glob(IMAGES_PATH + "*.png")

    if images_to_be_loaded == -1:
        images_to_be_loaded = len(train_ids)
        print(images_to_be_loaded)

    X_train = np.zeros((images_to_be_loaded, img_height, img_width, 3), dtype=np.float32)
    Y_train = np.zeros((images_to_be_loaded, img_height, img_width), dtype=np.uint8)

    print('Resizing training images and masks: ' + str(images_to_be_loaded))
    for n, id_ in tqdm(enumerate(train_ids)):
        if n == images_to_be_loaded:
            break

        image_path = id_
        mask_path = image_path.replace("images", "masks")

        image = imread(image_path)
        mask_ = imread(mask_path)

        mask = np.zeros((img_height, img_width), dtype=np.bool_)

        pillow_image = Image.fromarray(image)

        pillow_image = pillow_image.resize((img_height, img_width))
        image = np.array(pillow_image)

        X_train[n] = image / 255

        pillow_mask = Image.fromarray(mask_)
        pillow_mask = pillow_mask.resize((img_height, img_width), resample=Image.LANCZOS)
        mask_ = np.array(pillow_mask)

        for i in range(img_height):
            for j in range(img_width):
                if (mask_[i, j] >= 127).all():
                    mask[i, j] = 1

        Y_train[n] = mask

    Y_train = np.expand_dims(Y_train, axis=-1)

    return X_train, Y_train
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
X, Y = load_data(256, 256, -1, 'cvc-clinicdb')
# Out:
# 612
# Resizing training images and masks: 612
# 612it [04:18,  2.36it/s]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, shuffle= True, random_state = 58800)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.111, shuffle= True, random_state = 58800)
len(x_valid)
# Out:
# 62

# %%
# Defining the augmentations
import albumentations as albu
aug_train = albu.Compose([
    albu.HorizontalFlip(),
    albu.VerticalFlip(),
    albu.ColorJitter(brightness=(0.6,1.6), contrast=0.2, saturation=0.1, hue=0.01, always_apply=True),
    albu.Affine(scale=(0.5,1.5), translate_percent=(-0.125,0.125), rotate=(-180,180), shear=(-22.5,22), always_apply=True),
])

def augment_images():
    x_train_out = []
    y_train_out = []

    for i in range (len(x_train)):
        ug = aug_train(image=x_train[i], mask=y_train[i])
        x_train_out.append(ug['image'])  
        y_train_out.append(ug['mask'])

    return np.array(x_train_out), np.array(y_train_out)

# %%
image_augmented, mask_augmented = augment_images()

# %%
import tensorflow as tf
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, multiply, Permute, Concatenate, Conv2D, Add, Activation, Lambda
from tensorflow.keras import backend as K
from tensorflow.keras.activations import sigmoid

def cbam_block(cbam_feature, ratio=8):
    cbam_feature = channel_attention(cbam_feature, ratio)
    cbam_feature = spatial_attention(cbam_feature)
    return cbam_feature

def channel_attention(input_feature, ratio=8):
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    channel = input_feature.shape[channel_axis]
    
    shared_layer_one = Dense(channel//ratio, activation='relu', kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
    shared_layer_two = Dense(channel, kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
    
    avg_pool = GlobalAveragePooling2D()(input_feature)    
    avg_pool = Reshape((1,1,channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1,1,channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)

    cbam_feature = Add()([avg_pool,max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)

    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)

    return multiply([input_feature, cbam_feature])

def spatial_attention(input_feature):
    kernel_size = 7

    if K.image_data_format() == "channels_first":
        channel = input_feature.shape[1]
        cbam_feature = Permute((2,3,1))(input_feature)
    else:
        channel = input_feature.shape[-1]
        cbam_feature = input_feature

    avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
    
    max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
    
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    
    cbam_feature = Conv2D(filters = 1,kernel_size=kernel_size,strides=1,padding='same',activation='sigmoid',kernel_initializer='he_normal',use_bias=False)(concat)	
    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)
    return multiply([input_feature, cbam_feature])

# %%
from keras.layers import BatchNormalization, add
from keras.layers import Conv2D

kernel_initializer = 'he_uniform'


def conv_block_2D(x, filters, block_type, repeat=1, dilation_rate=1, size=3, padding='same'):
    result = x

    for i in range(0, repeat):

        if block_type == 'separated':
            result = separated_conv2D_block(result, filters, size=size, padding=padding)
        elif block_type == 'duckv2':
            result = duckv2_conv2D_block(result, filters, size=size)
        elif block_type == 'midscope':
            result = midscope_conv2D_block(result, filters)
        elif block_type == 'widescope':
            result = widescope_conv2D_block(result, filters)
        elif block_type == 'resnet':
            result = resnet_conv2D_block(result, filters, dilation_rate)
        elif block_type == 'conv':
            result = Conv2D(filters, (size, size),
                            activation='relu', kernel_initializer=kernel_initializer, padding=padding)(result)
        elif block_type == 'double_convolution':
            result = double_convolution_with_batch_normalization(result, filters, dilation_rate)

        else:
            return None

    return result


def duckv2_conv2D_block(x, filters, size):
    x = BatchNormalization(axis=-1)(x)
    x1 = widescope_conv2D_block(x, filters)

    x2 = midscope_conv2D_block(x, filters)

    x3 = conv_block_2D(x, filters, 'resnet', repeat=1)

    x4 = conv_block_2D(x, filters, 'resnet', repeat=2)

    x5 = conv_block_2D(x, filters, 'resnet', repeat=3)

    x6 = separated_conv2D_block(x, filters, size=6, padding='same')

    x = add([x1, x2, x3, x4, x5, x6])

    x = BatchNormalization(axis=-1)(x)

    return x


def separated_conv2D_block(x, filters, size=3, padding='same'):
    x = Conv2D(filters, (1, size), activation='relu', kernel_initializer=kernel_initializer, padding=padding)(x)

    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters, (size, 1), activation='relu', kernel_initializer=kernel_initializer, padding=padding)(x)

    x = BatchNormalization(axis=-1)(x)

    return x


def midscope_conv2D_block(x, filters):
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=1)(x)

    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=2)(x)

    x = BatchNormalization(axis=-1)(x)

    return x


def widescope_conv2D_block(x, filters):
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=1)(x)

    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=2)(x)

    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=3)(x)

    x = BatchNormalization(axis=-1)(x)

    return x


def resnet_conv2D_block(x, filters, dilation_rate=1):
    x1 = Conv2D(filters, (1, 1), activation='relu', kernel_initializer=kernel_initializer, padding='same',
                dilation_rate=dilation_rate)(x)

    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=dilation_rate)(x)
    x = BatchNormalization(axis=-1)(x)
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=dilation_rate)(x)
    x = BatchNormalization(axis=-1)(x)
    x_final = add([x, x1])

    x_final = BatchNormalization(axis=-1)(x_final)

    return x_final


def double_convolution_with_batch_normalization(x, filters, dilation_rate=1):
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=dilation_rate)(x)
    x = BatchNormalization(axis=-1)(x)
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=dilation_rate)(x)
    x = BatchNormalization(axis=-1)(x)

    return x

# %%
from tensorflow.keras.layers import Conv2D, UpSampling2D
from keras.models import Model


kernel_initializer = 'he_uniform'
interpolation = "nearest"



def create_model(img_height, img_width, input_chanels, out_classes, starting_filters):
    input_layer = tf.keras.layers.Input((img_height, img_width, input_chanels))

    print('Starting DUCK-Net')

    p1 = Conv2D(starting_filters * 2, 2, strides=2, padding='same')(input_layer)
    p2 = Conv2D(starting_filters * 4, 2, strides=2, padding='same')(p1)
    p3 = Conv2D(starting_filters * 8, 2, strides=2, padding='same')(p2)
    p4 = Conv2D(starting_filters * 16, 2, strides=2, padding='same')(p3)
    p5 = Conv2D(starting_filters * 32, 2, strides=2, padding='same')(p4)

    t0 = conv_block_2D(input_layer, starting_filters, 'duckv2', repeat=1)
    t0cb = cbam_block(t0)

    l1i = Conv2D(starting_filters * 2, 2, strides=2, padding='same')(t0)
    l1icb = cbam_block(l1i)
    s1 = add([l1icb, p1])
    t1 = conv_block_2D(s1, starting_filters * 2, 'duckv2', repeat=1)

    l2i = Conv2D(starting_filters * 4, 2, strides=2, padding='same')(t1)
    l2icb = cbam_block(l2i)
    s2 = add([l2icb, p2])
    t2 = conv_block_2D(s2, starting_filters * 4, 'duckv2', repeat=1)

    l3i = Conv2D(starting_filters * 8, 2, strides=2, padding='same')(t2)
    l3icb = cbam_block(l3i)
    s3 = add([l3icb, p3])
    t3 = conv_block_2D(s3, starting_filters * 8, 'duckv2', repeat=1)

    l4i = Conv2D(starting_filters * 16, 2, strides=2, padding='same')(t3)
    l4icb = cbam_block(l4i)
    s4 = add([l4icb, p4])
    t4 = conv_block_2D(s4, starting_filters * 16, 'duckv2', repeat=1)

    l5i = Conv2D(starting_filters * 32, 2, strides=2, padding='same')(t4)
    s5 = add([l5i, p5])
    t51 = conv_block_2D(s5, starting_filters * 32, 'resnet', repeat=2)
    t53 = conv_block_2D(t51, starting_filters * 16, 'resnet', repeat=2)
    
    #----------------------------------------------------------------------------------#

    l5o = UpSampling2D((2, 2), interpolation=interpolation)(t53)
    c4 = add([l5o, l4icb])
    q4 = conv_block_2D(c4, starting_filters * 8, 'duckv2', repeat=1)
    q4 = cbam_block(q4)
    

    l4o = UpSampling2D((2, 2), interpolation=interpolation)(q4)
    c3 = add([l4o, l3icb])
    q3 = conv_block_2D(c3, starting_filters * 4, 'duckv2', repeat=1)
    q3 = cbam_block(q3)


    l3o = UpSampling2D((2, 2), interpolation=interpolation)(q3)
    c2 = add([l3o, l2icb])
    q6 = conv_block_2D(c2, starting_filters * 2, 'duckv2', repeat=1)
    q6 = cbam_block(q6)
    #print(q6.shape)
    
    l2o = UpSampling2D((2, 2), interpolation=interpolation)(q6)
    c1 = add([l2o, l1icb])
    q1 = conv_block_2D(c1, starting_filters, 'duckv2', repeat=1)
    q1 = cbam_block(q1)
    #print(q1.shape)

    l1o = UpSampling2D((2, 2), interpolation=interpolation)(q1)
    c0 = add([l1o, t0cb])
    z1 = conv_block_2D(c0, starting_filters, 'duckv2', repeat=1)
    #print(z1.shape)

    output = Conv2D(out_classes, (1, 1), activation='sigmoid')(z1)

    model = Model(inputs=input_layer, outputs=output)

    return model

# %%
model = create_model(img_height=256, img_width=256, input_chanels=3, out_classes=1, starting_filters=17)
# Out:
# Starting DUCK-Net

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  batch_normalization (Batch  (None, 256, 256, 3)          12        ['input_1[0][0]']
#  Normalization)
#
#  conv2d_20 (Conv2D)          (None, 256, 256, 17)         476       ['batch_normalization[0][0]']
#
#  batch_normalization_15 (Ba  (None, 256, 256, 17)         68        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_15[0][0]
#                                                                     ']
#
#  batch_normalization_16 (Ba  (None, 256, 256, 17)         68        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 256, 256, 17)         68        ['batch_normalization[0][0]']
#
#  add_3 (Add)                 (None, 256, 256, 17)         0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'conv2d_19[0][0]']
#
#  batch_normalization_17 (Ba  (None, 256, 256, 17)         68        ['add_3[0][0]']
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 17)         476       ['batch_normalization[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_17[0][0]
#                                                                     ']
#
#  batch_normalization_9 (Bat  (None, 256, 256, 17)         68        ['conv2d_14[0][0]']
#  chNormalization)
#
#  batch_normalization_18 (Ba  (None, 256, 256, 17)         68        ['conv2d_23[0][0]']
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_24 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_10 (Ba  (None, 256, 256, 17)         68        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 256, 256, 17)         68        ['batch_normalization[0][0]']
#
#  batch_normalization_19 (Ba  (None, 256, 256, 17)         68        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 256, 256, 17)         306       ['batch_normalization_17[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, 256, 256, 17)         0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'conv2d_13[0][0]']
#
#  add_4 (Add)                 (None, 256, 256, 17)         0         ['batch_normalization_19[0][0]
#                                                                     ',
#                                                                      'conv2d_22[0][0]']
#
#  batch_normalization_11 (Ba  (None, 256, 256, 17)         68        ['add_1[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 256, 256, 17)         68        ['add_4[0][0]']
#  tchNormalization)
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 17)         476       ['batch_normalization[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 256, 256, 17)         476       ['batch_normalization[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_20[0][0]
#                                                                     ']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 17)         68        ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 256, 256, 17)         68        ['conv2d_11[0][0]']
#  chNormalization)
#
#  batch_normalization_12 (Ba  (None, 256, 256, 17)         68        ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 256, 256, 17)         68        ['conv2d_26[0][0]']
#  tchNormalization)
#
#  conv2d_6 (Conv2D)           (None, 256, 256, 17)         2618      ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 256, 256, 17)         476       ['batch_normalization[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 256, 256, 17)         2618      ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 256, 256, 17)         323       ['batch_normalization[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256, 256, 17)         68        ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 256, 256, 17)         68        ['conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 256, 256, 17)         68        ['conv2d_12[0][0]']
#  chNormalization)
#
#  conv2d_10 (Conv2D)          (None, 256, 256, 17)         68        ['batch_normalization[0][0]']
#
#  batch_normalization_13 (Ba  (None, 256, 256, 17)         68        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 17)         306       ['batch_normalization_11[0][0]
#                                                                     ']
#
#  batch_normalization_22 (Ba  (None, 256, 256, 17)         68        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 256, 256, 17)         306       ['batch_normalization_20[0][0]
#                                                                     ']
#
#  batch_normalization_24 (Ba  (None, 256, 256, 17)         68        ['conv2d_28[0][0]']
#  tchNormalization)
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 17)         2618      ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 256, 256, 17)         2618      ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 256, 256, 17)         0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv2d_10[0][0]']
#
#  add_2 (Add)                 (None, 256, 256, 17)         0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'conv2d_16[0][0]']
#
#  add_5 (Add)                 (None, 256, 256, 17)         0         ['batch_normalization_22[0][0]
#                                                                     ',
#                                                                      'conv2d_25[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 256, 256, 17)         1751      ['batch_normalization_24[0][0]
#                                                                     ']
#
#  batch_normalization_3 (Bat  (None, 256, 256, 17)         68        ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 256, 256, 17)         68        ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 17)         68        ['add[0][0]']
#  chNormalization)
#
#  batch_normalization_14 (Ba  (None, 256, 256, 17)         68        ['add_2[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 256, 256, 17)         68        ['add_5[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 256, 256, 17)         68        ['conv2d_29[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 256, 256, 17)         0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_5[0][0]
#                                                                     ',
#                                                                      'batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_14[0][0
#                                                                     ]',
#                                                                      'batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ']
#
#  batch_normalization_26 (Ba  (None, 256, 256, 17)         68        ['add_6[0][0]']
#  tchNormalization)
#
#  conv2d_31 (Conv2D)          (None, 128, 128, 34)         2346      ['batch_normalization_26[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 34)                   0         ['conv2d_31[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_1 (Gl  (None, 34)                   0         ['conv2d_31[0][0]']
#  obalMaxPooling2D)
#
#  reshape_2 (Reshape)         (None, 1, 1, 34)             0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  reshape_3 (Reshape)         (None, 1, 1, 34)             0         ['global_max_pooling2d_1[0][0]
#                                                                     ']
#
#  dense_2 (Dense)             (None, 1, 1, 4)              140       ['reshape_2[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  dense_3 (Dense)             (None, 1, 1, 34)             170       ['dense_2[0][0]',
#                                                                      'dense_2[1][0]']
#
#  add_8 (Add)                 (None, 1, 1, 34)             0         ['dense_3[0][0]',
#                                                                      'dense_3[1][0]']
#
#  activation_1 (Activation)   (None, 1, 1, 34)             0         ['add_8[0][0]']
#
#  multiply_2 (Multiply)       (None, 128, 128, 34)         0         ['conv2d_31[0][0]',
#                                                                      'activation_1[0][0]']
#
#  lambda_2 (Lambda)           (None, 128, 128, 1)          0         ['multiply_2[0][0]']
#
#  lambda_3 (Lambda)           (None, 128, 128, 1)          0         ['multiply_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 128, 128, 2)          0         ['lambda_2[0][0]',
#  )                                                                   'lambda_3[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 128, 128, 1)          98        ['concatenate_1[0][0]']
#
#  multiply_3 (Multiply)       (None, 128, 128, 34)         0         ['multiply_2[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  conv2d (Conv2D)             (None, 128, 128, 34)         442       ['input_1[0][0]']
#
#  add_9 (Add)                 (None, 128, 128, 34)         0         ['multiply_3[0][0]',
#                                                                      'conv2d[0][0]']
#
#  batch_normalization_27 (Ba  (None, 128, 128, 34)         136       ['add_9[0][0]']
#  tchNormalization)
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_27[0][0]
#                                                                     ']
#
#  batch_normalization_42 (Ba  (None, 128, 128, 34)         136       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_42[0][0]
#                                                                     ']
#
#  batch_normalization_43 (Ba  (None, 128, 128, 34)         136       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  conv2d_47 (Conv2D)          (None, 128, 128, 34)         1190      ['batch_normalization_27[0][0]
#                                                                     ']
#
#  add_13 (Add)                (None, 128, 128, 34)         0         ['batch_normalization_43[0][0]
#                                                                     ',
#                                                                      'conv2d_47[0][0]']
#
#  batch_normalization_44 (Ba  (None, 128, 128, 34)         136       ['add_13[0][0]']
#  tchNormalization)
#
#  conv2d_42 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_44[0][0]
#                                                                     ']
#
#  batch_normalization_36 (Ba  (None, 128, 128, 34)         136       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 128, 128, 34)         136       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  conv2d_43 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_45[0][0]
#                                                                     ']
#
#  batch_normalization_37 (Ba  (None, 128, 128, 34)         136       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  conv2d_41 (Conv2D)          (None, 128, 128, 34)         1190      ['batch_normalization_27[0][0]
#                                                                     ']
#
#  batch_normalization_46 (Ba  (None, 128, 128, 34)         136       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  conv2d_50 (Conv2D)          (None, 128, 128, 34)         1190      ['batch_normalization_44[0][0]
#                                                                     ']
#
#  add_11 (Add)                (None, 128, 128, 34)         0         ['batch_normalization_37[0][0]
#                                                                     ',
#                                                                      'conv2d_41[0][0]']
#
#  add_14 (Add)                (None, 128, 128, 34)         0         ['batch_normalization_46[0][0]
#                                                                     ',
#                                                                      'conv2d_50[0][0]']
#
#  batch_normalization_38 (Ba  (None, 128, 128, 34)         136       ['add_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 128, 128, 34)         136       ['add_14[0][0]']
#  tchNormalization)
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_47[0][0]
#                                                                     ']
#
#  batch_normalization_28 (Ba  (None, 128, 128, 34)         136       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 128, 128, 34)         136       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 128, 128, 34)         136       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 128, 128, 34)         136       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  conv2d_34 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 128, 128, 34)         6970      ['batch_normalization_27[0][0]
#                                                                     ']
#
#  batch_normalization_29 (Ba  (None, 128, 128, 34)         136       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 128, 128, 34)         136       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 128, 128, 34)         136       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  conv2d_38 (Conv2D)          (None, 128, 128, 34)         1190      ['batch_normalization_27[0][0]
#                                                                     ']
#
#  batch_normalization_40 (Ba  (None, 128, 128, 34)         136       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  conv2d_44 (Conv2D)          (None, 128, 128, 34)         1190      ['batch_normalization_38[0][0]
#                                                                     ']
#
#  batch_normalization_49 (Ba  (None, 128, 128, 34)         136       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  conv2d_53 (Conv2D)          (None, 128, 128, 34)         1190      ['batch_normalization_47[0][0]
#                                                                     ']
#
#  batch_normalization_51 (Ba  (None, 128, 128, 34)         136       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  conv2d_35 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 128, 128, 34)         10438     ['batch_normalization_31[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 128, 128, 34)         0         ['batch_normalization_34[0][0]
#                                                                     ',
#                                                                      'conv2d_38[0][0]']
#
#  add_12 (Add)                (None, 128, 128, 34)         0         ['batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'conv2d_44[0][0]']
#
#  add_15 (Add)                (None, 128, 128, 34)         0         ['batch_normalization_49[0][0]
#                                                                     ',
#                                                                      'conv2d_53[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 128, 128, 34)         6970      ['batch_normalization_51[0][0]
#                                                                     ']
#
#  batch_normalization_30 (Ba  (None, 128, 128, 34)         136       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 128, 128, 34)         136       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 128, 128, 34)         136       ['add_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 128, 128, 34)         136       ['add_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_50 (Ba  (None, 128, 128, 34)         136       ['add_15[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 128, 128, 34)         136       ['conv2d_57[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 128, 128, 34)         0         ['batch_normalization_30[0][0]
#                                                                     ',
#                                                                      'batch_normalization_32[0][0]
#                                                                     ',
#                                                                      'batch_normalization_35[0][0]
#                                                                     ',
#                                                                      'batch_normalization_41[0][0]
#                                                                     ',
#                                                                      'batch_normalization_50[0][0]
#                                                                     ',
#                                                                      'batch_normalization_52[0][0]
#                                                                     ']
#
#  batch_normalization_53 (Ba  (None, 128, 128, 34)         136       ['add_16[0][0]']
#  tchNormalization)
#
#  conv2d_58 (Conv2D)          (None, 64, 64, 68)           9316      ['batch_normalization_53[0][0]
#                                                                     ']
#
#  global_average_pooling2d_2  (None, 68)                   0         ['conv2d_58[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_2 (Gl  (None, 68)                   0         ['conv2d_58[0][0]']
#  obalMaxPooling2D)
#
#  reshape_4 (Reshape)         (None, 1, 1, 68)             0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  reshape_5 (Reshape)         (None, 1, 1, 68)             0         ['global_max_pooling2d_2[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1, 1, 8)              552       ['reshape_4[0][0]',
#                                                                      'reshape_5[0][0]']
#
#  dense_5 (Dense)             (None, 1, 1, 68)             612       ['dense_4[0][0]',
#                                                                      'dense_4[1][0]']
#
#  add_17 (Add)                (None, 1, 1, 68)             0         ['dense_5[0][0]',
#                                                                      'dense_5[1][0]']
#
#  activation_2 (Activation)   (None, 1, 1, 68)             0         ['add_17[0][0]']
#
#  multiply_4 (Multiply)       (None, 64, 64, 68)           0         ['conv2d_58[0][0]',
#                                                                      'activation_2[0][0]']
#
#  lambda_4 (Lambda)           (None, 64, 64, 1)            0         ['multiply_4[0][0]']
#
#  lambda_5 (Lambda)           (None, 64, 64, 1)            0         ['multiply_4[0][0]']
#
#  concatenate_2 (Concatenate  (None, 64, 64, 2)            0         ['lambda_4[0][0]',
#  )                                                                   'lambda_5[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 64, 64, 1)            98        ['concatenate_2[0][0]']
#
#  multiply_5 (Multiply)       (None, 64, 64, 68)           0         ['multiply_4[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 68)           9316      ['conv2d[0][0]']
#
#  add_18 (Add)                (None, 64, 64, 68)           0         ['multiply_5[0][0]',
#                                                                      'conv2d_1[0][0]']
#
#  batch_normalization_54 (Ba  (None, 64, 64, 68)           272       ['add_18[0][0]']
#  tchNormalization)
#
#  conv2d_75 (Conv2D)          (None, 64, 64, 68)           41684     ['batch_normalization_54[0][0]
#                                                                     ']
#
#  batch_normalization_69 (Ba  (None, 64, 64, 68)           272       ['conv2d_75[0][0]']
#  tchNormalization)
#
#  conv2d_76 (Conv2D)          (None, 64, 64, 68)           41684     ['batch_normalization_69[0][0]
#                                                                     ']
#
#  batch_normalization_70 (Ba  (None, 64, 64, 68)           272       ['conv2d_76[0][0]']
# ...
#                                                                     ]']
#
#  conv2d_275 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_273[0][0
#                                                                     ]']
#
#  batch_normalization_265 (B  (None, 256, 256, 17)         68        ['conv2d_266[0][0]']
#  atchNormalization)
#
#  conv2d_264 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_255[0][0
#                                                                     ]']
#
#  batch_normalization_274 (B  (None, 256, 256, 17)         68        ['conv2d_275[0][0]']
#  atchNormalization)
#
#  conv2d_273 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_272[0][0
#                                                                     ]']
#
#  add_87 (Add)                (None, 256, 256, 17)         0         ['batch_normalization_265[0][0
#                                                                     ]',
#                                                                      'conv2d_264[0][0]']
#
#  add_90 (Add)                (None, 256, 256, 17)         0         ['batch_normalization_274[0][0
#                                                                     ]',
#                                                                      'conv2d_273[0][0]']
#
#  batch_normalization_266 (B  (None, 256, 256, 17)         68        ['add_87[0][0]']
#  atchNormalization)
#
#  batch_normalization_275 (B  (None, 256, 256, 17)         68        ['add_90[0][0]']
#  atchNormalization)
#
#  conv2d_256 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_255[0][0
#                                                                     ]']
#
#  conv2d_262 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_255[0][0
#                                                                     ]']
#
#  conv2d_268 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_266[0][0
#                                                                     ]']
#
#  conv2d_277 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_275[0][0
#                                                                     ]']
#
#  batch_normalization_256 (B  (None, 256, 256, 17)         68        ['conv2d_256[0][0]']
#  atchNormalization)
#
#  batch_normalization_261 (B  (None, 256, 256, 17)         68        ['conv2d_262[0][0]']
#  atchNormalization)
#
#  batch_normalization_267 (B  (None, 256, 256, 17)         68        ['conv2d_268[0][0]']
#  atchNormalization)
#
#  batch_normalization_276 (B  (None, 256, 256, 17)         68        ['conv2d_277[0][0]']
#  atchNormalization)
#
#  conv2d_257 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_256[0][0
#                                                                     ]']
#
#  conv2d_259 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_255[0][0
#                                                                     ]']
#
#  conv2d_263 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_261[0][0
#                                                                     ]']
#
#  conv2d_269 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_267[0][0
#                                                                     ]']
#
#  conv2d_278 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_276[0][0
#                                                                     ]']
#
#  conv2d_279 (Conv2D)         (None, 256, 256, 17)         1751      ['batch_normalization_255[0][0
#                                                                     ]']
#
#  batch_normalization_257 (B  (None, 256, 256, 17)         68        ['conv2d_257[0][0]']
#  atchNormalization)
#
#  batch_normalization_259 (B  (None, 256, 256, 17)         68        ['conv2d_259[0][0]']
#  atchNormalization)
#
#  batch_normalization_262 (B  (None, 256, 256, 17)         68        ['conv2d_263[0][0]']
#  atchNormalization)
#
#  conv2d_261 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_255[0][0
#                                                                     ]']
#
#  batch_normalization_268 (B  (None, 256, 256, 17)         68        ['conv2d_269[0][0]']
#  atchNormalization)
#
#  conv2d_267 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_266[0][0
#                                                                     ]']
#
#  batch_normalization_277 (B  (None, 256, 256, 17)         68        ['conv2d_278[0][0]']
#  atchNormalization)
#
#  conv2d_276 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_275[0][0
#                                                                     ]']
#
#  batch_normalization_279 (B  (None, 256, 256, 17)         68        ['conv2d_279[0][0]']
#  atchNormalization)
#
#  conv2d_258 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_257[0][0
#                                                                     ]']
#
#  conv2d_260 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_259[0][0
#                                                                     ]']
#
#  add_86 (Add)                (None, 256, 256, 17)         0         ['batch_normalization_262[0][0
#                                                                     ]',
#                                                                      'conv2d_261[0][0]']
#
#  add_88 (Add)                (None, 256, 256, 17)         0         ['batch_normalization_268[0][0
#                                                                     ]',
#                                                                      'conv2d_267[0][0]']
#
#  add_91 (Add)                (None, 256, 256, 17)         0         ['batch_normalization_277[0][0
#                                                                     ]',
#                                                                      'conv2d_276[0][0]']
#
#  conv2d_280 (Conv2D)         (None, 256, 256, 17)         1751      ['batch_normalization_279[0][0
#                                                                     ]']
#
#  batch_normalization_258 (B  (None, 256, 256, 17)         68        ['conv2d_258[0][0]']
#  atchNormalization)
#
#  batch_normalization_260 (B  (None, 256, 256, 17)         68        ['conv2d_260[0][0]']
#  atchNormalization)
#
#  batch_normalization_263 (B  (None, 256, 256, 17)         68        ['add_86[0][0]']
#  atchNormalization)
#
#  batch_normalization_269 (B  (None, 256, 256, 17)         68        ['add_88[0][0]']
#  atchNormalization)
#
#  batch_normalization_278 (B  (None, 256, 256, 17)         68        ['add_91[0][0]']
#  atchNormalization)
#
#  batch_normalization_280 (B  (None, 256, 256, 17)         68        ['conv2d_280[0][0]']
#  atchNormalization)
#
#  add_92 (Add)                (None, 256, 256, 17)         0         ['batch_normalization_258[0][0
#                                                                     ]',
#                                                                      'batch_normalization_260[0][0
#                                                                     ]',
#                                                                      'batch_normalization_263[0][0
#                                                                     ]',
#                                                                      'batch_normalization_269[0][0
#                                                                     ]',
#                                                                      'batch_normalization_278[0][0
#                                                                     ]',
#                                                                      'batch_normalization_280[0][0
#                                                                     ]']
#
#  batch_normalization_281 (B  (None, 256, 256, 17)         68        ['add_92[0][0]']
#  atchNormalization)
#
#  conv2d_281 (Conv2D)         (None, 256, 256, 1)          18        ['batch_normalization_281[0][0
#                                                                     ]']
#
# ==================================================================================================
# Total params: 38953448 (148.60 MB)
# Trainable params: 38900028 (148.39 MB)
# Non-trainable params: 53420 (208.67 KB)
# __________________________________________________________________________________________________

# %%
import keras.backend as K
import tensorflow as tf


def dice_metric_loss(ground_truth, predictions, smooth=1e-6):
    ground_truth = K.cast(ground_truth, tf.float32)
    predictions = K.cast(predictions, tf.float32)
    ground_truth = K.flatten(ground_truth)
    predictions = K.flatten(predictions)
    intersection = K.sum(predictions * ground_truth)
    union = K.sum(predictions) + K.sum(ground_truth)

    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

# %%
learning_rate = 1e-4
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss=dice_metric_loss , metrics=['acc'])

# %%
import gc
EPOCHS = 50
min_loss_for_saving = 0.3
step = 0

for epoch in range(0, EPOCHS):
    
    print(f'Training, epoch {epoch}')
    print('Learning Rate: ' + str(learning_rate))

    step += 1
    
    model.fit(x=image_augmented, y=mask_augmented, epochs=1, batch_size=4, validation_data=(x_valid, y_valid), verbose=1 )
    
    prediction_valid = model.predict(x_valid, verbose=0)
    loss_valid = dice_metric_loss(y_valid, prediction_valid)
    
    loss_valid = loss_valid.numpy()
    print("Loss Validation: " + str(loss_valid))
        
    prediction_test = model.predict(x_test, verbose=0)
    loss_test = dice_metric_loss(y_test, prediction_test)
    loss_test = loss_test.numpy()
    print("Loss Test: " + str(loss_test))
     
    if min_loss_for_saving > loss_valid:
        min_loss_for_saving = loss_valid
        print("Saved model with val_loss: ", loss_valid)
        model.save("/kaggle/working/duck-net-cbam-cbam_1.h5")
    if epoch==49:
        model.save("/kaggle/working/duck-net-cbam-cbam_2.h5")
        
    #del image_augmented
    #del mask_augmented

    gc.collect()
# Out:
# Training, epoch 0
# Learning Rate: 0.0001
# 122/122 [==============================] - 250s 403ms/step - loss: 0.9112 - acc: 0.6514 - val_loss: 0.7764 - val_acc: 0.9046
# Loss Validation: 0.7674766
# Loss Test: 0.7235615
# Training, epoch 1
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 331ms/step - loss: 0.8745 - acc: 0.7786 - val_loss: 0.6959 - val_acc: 0.9265
# Loss Validation: 0.6895114
# Loss Test: 0.65015197
# Training, epoch 2
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 331ms/step - loss: 0.8474 - acc: 0.8455 - val_loss: 0.7164 - val_acc: 0.9383
# Loss Validation: 0.696558
# Loss Test: 0.64799625
# Training, epoch 3
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 331ms/step - loss: 0.8261 - acc: 0.8770 - val_loss: 0.7159 - val_acc: 0.9442
# Loss Validation: 0.70452654
# Loss Test: 0.6490474
# Training, epoch 4
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.8098 - acc: 0.8980 - val_loss: 0.6632 - val_acc: 0.9655
# Loss Validation: 0.6722872
# Loss Test: 0.6103817
# Training, epoch 5
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.7867 - acc: 0.9155 - val_loss: 0.6916 - val_acc: 0.9480
# Loss Validation: 0.6942616
# Loss Test: 0.63452256
# Training, epoch 6
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.7692 - acc: 0.9241 - val_loss: 0.6523 - val_acc: 0.9692
# Loss Validation: 0.64271665
# Loss Test: 0.57746637
# Training, epoch 7
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.7414 - acc: 0.9397 - val_loss: 0.6297 - val_acc: 0.9733
# Loss Validation: 0.6120382
# Loss Test: 0.54859626
# Training, epoch 8
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 332ms/step - loss: 0.7213 - acc: 0.9459 - val_loss: 0.6315 - val_acc: 0.9554
# Loss Validation: 0.6337341
# Loss Test: 0.5584557
# Training, epoch 9
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.6938 - acc: 0.9543 - val_loss: 0.5821 - val_acc: 0.9833
# Loss Validation: 0.5690579
# Loss Test: 0.50323343
# Training, epoch 10
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 332ms/step - loss: 0.6699 - acc: 0.9621 - val_loss: 0.5146 - val_acc: 0.9866
# Loss Validation: 0.48795193
# Loss Test: 0.42258167
# Training, epoch 11
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.6344 - acc: 0.9678 - val_loss: 0.4939 - val_acc: 0.9790
# Loss Validation: 0.47751147
# Loss Test: 0.40562797
# Training, epoch 12
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.6014 - acc: 0.9717 - val_loss: 0.4787 - val_acc: 0.9899
# Loss Validation: 0.44815034
# Loss Test: 0.38470453
# Training, epoch 13
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.5723 - acc: 0.9777 - val_loss: 0.4311 - val_acc: 0.9906
# Loss Validation: 0.40846455
# Loss Test: 0.34334773
# Training, epoch 14
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.5236 - acc: 0.9812 - val_loss: 0.3805 - val_acc: 0.9924
# Loss Validation: 0.35658622
# Loss Test: 0.29615062
# Training, epoch 15
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.4915 - acc: 0.9834 - val_loss: 0.3603 - val_acc: 0.9932
# Loss Validation: 0.32896775
# Loss Test: 0.2731889
# Training, epoch 16
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.4545 - acc: 0.9862 - val_loss: 0.3314 - val_acc: 0.9926
# Loss Validation: 0.302522
# Loss Test: 0.2456271
# Training, epoch 17
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.4287 - acc: 0.9868 - val_loss: 0.2950 - val_acc: 0.9944
# Loss Validation: 0.26820356
# Loss Test: 0.21820384
# Saved model with val_loss:  0.26820356
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Training, epoch 18
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.3882 - acc: 0.9890 - val_loss: 0.2712 - val_acc: 0.9937
# Loss Validation: 0.25167215
# Loss Test: 0.19922459
# Saved model with val_loss:  0.25167215
# Training, epoch 19
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 331ms/step - loss: 0.3760 - acc: 0.9894 - val_loss: 0.3259 - val_acc: 0.9881
# Loss Validation: 0.2534933
# Loss Test: 0.19068104
# Training, epoch 20
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 331ms/step - loss: 0.3635 - acc: 0.9897 - val_loss: 0.3599 - val_acc: 0.9903
# Loss Validation: 0.33934027
# Loss Test: 0.26524776
# Training, epoch 21
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.3278 - acc: 0.9910 - val_loss: 0.2907 - val_acc: 0.9922
# Loss Validation: 0.26399428
# Loss Test: 0.1986013
# Training, epoch 22
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.3244 - acc: 0.9910 - val_loss: 0.2299 - val_acc: 0.9937
# Loss Validation: 0.21373105
# Loss Test: 0.15794122
# Saved model with val_loss:  0.21373105
# Training, epoch 23
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2948 - acc: 0.9918 - val_loss: 0.2471 - val_acc: 0.9922
# Loss Validation: 0.22220212
# Loss Test: 0.16129941
# Training, epoch 24
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2720 - acc: 0.9924 - val_loss: 0.1985 - val_acc: 0.9939
# Loss Validation: 0.17243809
# Loss Test: 0.13678187
# Saved model with val_loss:  0.17243809
# Training, epoch 25
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2589 - acc: 0.9927 - val_loss: 0.2534 - val_acc: 0.9914
# Loss Validation: 0.23739362
# Loss Test: 0.17870295
# Training, epoch 26
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2523 - acc: 0.9931 - val_loss: 0.1793 - val_acc: 0.9935
# Loss Validation: 0.17547846
# Loss Test: 0.1378563
# Training, epoch 27
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2353 - acc: 0.9934 - val_loss: 0.1783 - val_acc: 0.9937
# Loss Validation: 0.16204554
# Loss Test: 0.12678176
# Saved model with val_loss:  0.16204554
# Training, epoch 28
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2188 - acc: 0.9936 - val_loss: 0.1463 - val_acc: 0.9946
# Loss Validation: 0.13230824
# Loss Test: 0.108994365
# Saved model with val_loss:  0.13230824
# Training, epoch 29
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2075 - acc: 0.9935 - val_loss: 0.1521 - val_acc: 0.9943
# Loss Validation: 0.13390797
# Loss Test: 0.108359694
# Training, epoch 30
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2117 - acc: 0.9940 - val_loss: 0.2161 - val_acc: 0.9913
# Loss Validation: 0.19974405
# Loss Test: 0.15391219
# Training, epoch 31
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.2023 - acc: 0.9939 - val_loss: 0.1772 - val_acc: 0.9931
# Loss Validation: 0.16432595
# Loss Test: 0.12525159
# Training, epoch 32
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1921 - acc: 0.9940 - val_loss: 0.1599 - val_acc: 0.9935
# Loss Validation: 0.14706236
# Loss Test: 0.11408502
# Training, epoch 33
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1840 - acc: 0.9943 - val_loss: 0.1360 - val_acc: 0.9945
# Loss Validation: 0.12291813
# Loss Test: 0.10461199
# Saved model with val_loss:  0.12291813
# Training, epoch 34
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1778 - acc: 0.9942 - val_loss: 0.1342 - val_acc: 0.9945
# Loss Validation: 0.12114388
# Loss Test: 0.09718025
# Saved model with val_loss:  0.12114388
# Training, epoch 35
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 331ms/step - loss: 0.1712 - acc: 0.9945 - val_loss: 0.1515 - val_acc: 0.9937
# Loss Validation: 0.13744086
# Loss Test: 0.10869408
# Training, epoch 36
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1626 - acc: 0.9948 - val_loss: 0.1783 - val_acc: 0.9925
# Loss Validation: 0.16254675
# Loss Test: 0.12831736
# Training, epoch 37
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1568 - acc: 0.9949 - val_loss: 0.1490 - val_acc: 0.9940
# Loss Validation: 0.1341598
# Loss Test: 0.110857666
# Training, epoch 38
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1567 - acc: 0.9948 - val_loss: 0.2181 - val_acc: 0.9910
# Loss Validation: 0.20419323
# Loss Test: 0.16101873
# Training, epoch 39
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1555 - acc: 0.9949 - val_loss: 0.1385 - val_acc: 0.9940
# Loss Validation: 0.12658447
# Loss Test: 0.10349101
# Training, epoch 40
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1519 - acc: 0.9947 - val_loss: 0.1777 - val_acc: 0.9925
# Loss Validation: 0.16292328
# Loss Test: 0.120189786
# Training, epoch 41
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1456 - acc: 0.9950 - val_loss: 0.1356 - val_acc: 0.9941
# Loss Validation: 0.12486577
# Loss Test: 0.09701991
# Training, epoch 42
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1452 - acc: 0.9950 - val_loss: 0.1493 - val_acc: 0.9934
# Loss Validation: 0.14259398
# Loss Test: 0.11451441
# Training, epoch 43
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1443 - acc: 0.9951 - val_loss: 0.1964 - val_acc: 0.9916
# Loss Validation: 0.19014412
# Loss Test: 0.13755798
# Training, epoch 44
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1462 - acc: 0.9949 - val_loss: 0.2034 - val_acc: 0.9912
# Loss Validation: 0.1942153
# Loss Test: 0.1554755
# Training, epoch 45
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 329ms/step - loss: 0.1436 - acc: 0.9949 - val_loss: 0.1395 - val_acc: 0.9939
# Loss Validation: 0.12705606
# Loss Test: 0.1031934
# Training, epoch 46
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1367 - acc: 0.9951 - val_loss: 0.1496 - val_acc: 0.9934
# Loss Validation: 0.14073879
# Loss Test: 0.11151886
# Training, epoch 47
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1357 - acc: 0.9952 - val_loss: 0.1264 - val_acc: 0.9941
# Loss Validation: 0.12129736
# Loss Test: 0.09463078
# Training, epoch 48
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1328 - acc: 0.9954 - val_loss: 0.1332 - val_acc: 0.9941
# Loss Validation: 0.12070304
# Loss Test: 0.09310144
# Saved model with val_loss:  0.12070304
# Training, epoch 49
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.1316 - acc: 0.9952 - val_loss: 0.1301 - val_acc: 0.9939
# Loss Validation: 0.11325103
# Loss Test: 0.09439349
# Saved model with val_loss:  0.11325103

# %%
from sklearn.metrics import jaccard_score, precision_score, recall_score, accuracy_score, f1_score
print("Loading the model")

model = tf.keras.models.load_model('/kaggle/working/duck-net-cbam-cbam_1.h5', custom_objects={'dice_metric_loss':dice_metric_loss})

prediction_train = model.predict(x_train, batch_size=4)
prediction_valid = model.predict(x_valid, batch_size=4)
prediction_test = model.predict(x_test, batch_size=4)

print("Predictions done")

dice_train = f1_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                           np.ndarray.flatten(prediction_train > 0.5))
dice_test = f1_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                          np.ndarray.flatten(prediction_test > 0.5))
dice_valid = f1_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                           np.ndarray.flatten(prediction_valid > 0.5))

print("Dice finished")


miou_train = jaccard_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                           np.ndarray.flatten(prediction_train > 0.5))
miou_test = jaccard_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                          np.ndarray.flatten(prediction_test > 0.5))
miou_valid = jaccard_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                           np.ndarray.flatten(prediction_valid > 0.5))

print("Miou finished")


precision_train = precision_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                                  np.ndarray.flatten(prediction_train > 0.5))
precision_test = precision_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                                 np.ndarray.flatten(prediction_test > 0.5))
precision_valid = precision_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                                  np.ndarray.flatten(prediction_valid > 0.5))

print("Precision finished")


recall_train = recall_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                            np.ndarray.flatten(prediction_train > 0.5))
recall_test = recall_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                           np.ndarray.flatten(prediction_test > 0.5))
recall_valid = recall_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                            np.ndarray.flatten(prediction_valid > 0.5))

print("Recall finished")


accuracy_train = accuracy_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                                np.ndarray.flatten(prediction_train > 0.5))
accuracy_test = accuracy_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                               np.ndarray.flatten(prediction_test > 0.5))
accuracy_valid = accuracy_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                                np.ndarray.flatten(prediction_valid > 0.5))


print("Accuracy finished")
# Out:
# Loading the model
# 122/122 [==============================] - 16s 84ms/step
# 16/16 [==============================] - 8s 88ms/step
# 16/16 [==============================] - 1s 87ms/step
# Predictions done
# Dice finished
# Miou finished
# Precision finished
# Recall finished
# Accuracy finished

# %%
final_file = '/kaggle/working/'+'results_'+'CBAM_CBAM_DUCK-Net'+ '.txt'
print(final_file)

with open(final_file, 'a') as f:
    f.write('clinic-db' + '\n\n')
    f.write('dice_train: ' + str(dice_train) + ' dice_valid: ' + str(dice_valid) + ' dice_test: ' + str(dice_test) + '\n\n')
    f.write('miou_train: ' + str(miou_train) + ' miou_valid: ' + str(miou_valid) + ' miou_test: ' + str(miou_test) + '\n\n')
    f.write('precision_train: ' + str(precision_train) + ' precision_valid: ' + str(precision_valid) + ' precision_test: ' + str(precision_test) + '\n\n')
    f.write('recall_train: ' + str(recall_train) + ' recall_valid: ' + str(recall_valid) + ' recall_test: ' + str(recall_test) + '\n\n')
    f.write('accuracy_train: ' + str(accuracy_train) + ' accuracy_valid: ' + str(accuracy_valid) + ' accuracy_test: ' + str(accuracy_test) + '\n\n\n\n')

print('File done')
# Out:
# /kaggle/working/results_CBAM_CBAM_DUCK-Net.txt
# File done

# %%
from IPython.display import FileLink
FileLink(r'duck-net-cbam-cbam_1.h5')
# Out:
# /kaggle/working/duck-net-cbam-cbam_1.h5
