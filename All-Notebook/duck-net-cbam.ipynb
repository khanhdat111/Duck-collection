# %%
import glob

import numpy as np
from PIL import Image
from skimage.io import imread
from tqdm import tqdm

folder_path = "/kaggle/input/cvc-clinic-png/"  # Add the path to your data directory


def load_data(img_height, img_width, images_to_be_loaded, dataset):
    IMAGES_PATH = folder_path + 'Original/'
    MASKS_PATH = folder_path + 'Ground Truth/'

    if dataset == 'kvasir':
        train_ids = glob.glob(IMAGES_PATH + "*.jpg")

    if dataset == 'cvc-clinicdb':
        train_ids = glob.glob(IMAGES_PATH + "*.png")
        #train_ids = train_ids[:30]

    if dataset == 'cvc-colondb' or dataset == 'etis-laribpolypdb':
        train_ids = glob.glob(IMAGES_PATH + "*.png")

    if images_to_be_loaded == -1:
        images_to_be_loaded = len(train_ids)
        print(images_to_be_loaded)

    X_train = np.zeros((images_to_be_loaded, img_height, img_width, 3), dtype=np.float32)
    Y_train = np.zeros((images_to_be_loaded, img_height, img_width), dtype=np.uint8)

    print('Resizing training images and masks: ' + str(images_to_be_loaded))
    for n, id_ in tqdm(enumerate(train_ids)):
        if n == images_to_be_loaded:
            break

        image_path = id_
        mask_path = image_path.replace("images", "masks")

        image = imread(image_path)
        mask_ = imread(mask_path)

        mask = np.zeros((img_height, img_width), dtype=np.bool_)

        pillow_image = Image.fromarray(image)

        pillow_image = pillow_image.resize((img_height, img_width))
        image = np.array(pillow_image)

        X_train[n] = image / 255

        pillow_mask = Image.fromarray(mask_)
        pillow_mask = pillow_mask.resize((img_height, img_width), resample=Image.LANCZOS)
        mask_ = np.array(pillow_mask)

        for i in range(img_height):
            for j in range(img_width):
                if (mask_[i, j] >= 127).all():
                    mask[i, j] = 1

        Y_train[n] = mask

    Y_train = np.expand_dims(Y_train, axis=-1)

    return X_train, Y_train

# %%
X, Y = load_data(256, 256, -1, 'cvc-clinicdb')
# Out:
# 612
# Resizing training images and masks: 612
# 612it [04:39,  2.19it/s]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, shuffle= True, random_state = 58800)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.111, shuffle= True, random_state = 58800)
len(x_valid)
# Out:
# 62

# %%
# Defining the augmentations
import albumentations as albu
aug_train = albu.Compose([
    albu.HorizontalFlip(),
    albu.VerticalFlip(),
    albu.ColorJitter(brightness=(0.6,1.6), contrast=0.2, saturation=0.1, hue=0.01, always_apply=True),
    albu.Affine(scale=(0.5,1.5), translate_percent=(-0.125,0.125), rotate=(-180,180), shear=(-22.5,22), always_apply=True),
])

def augment_images():
    x_train_out = []
    y_train_out = []

    for i in range (len(x_train)):
        ug = aug_train(image=x_train[i], mask=y_train[i])
        x_train_out.append(ug['image'])  
        y_train_out.append(ug['mask'])

    return np.array(x_train_out), np.array(y_train_out)

# %%
image_augmented, mask_augmented = augment_images()

# %%
import tensorflow as tf
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, multiply, Permute, Concatenate, Conv2D, Add, Activation, Lambda
from tensorflow.keras import backend as K
from tensorflow.keras.activations import sigmoid

def cbam_block(cbam_feature, ratio=8):
    cbam_feature = channel_attention(cbam_feature, ratio)
    cbam_feature = spatial_attention(cbam_feature)
    return cbam_feature

def channel_attention(input_feature, ratio=8):
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    channel = input_feature.shape[channel_axis]
    
    shared_layer_one = Dense(channel//ratio, activation='relu', kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
    shared_layer_two = Dense(channel, kernel_initializer='he_normal', use_bias=True, bias_initializer='zeros')
    
    avg_pool = GlobalAveragePooling2D()(input_feature)    
    avg_pool = Reshape((1,1,channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1,1,channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)

    cbam_feature = Add()([avg_pool,max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)

    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)

    return multiply([input_feature, cbam_feature])

def spatial_attention(input_feature):
    kernel_size = 7

    if K.image_data_format() == "channels_first":
        channel = input_feature.shape[1]
        cbam_feature = Permute((2,3,1))(input_feature)
    else:
        channel = input_feature.shape[-1]
        cbam_feature = input_feature

    avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
    
    max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
    
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    
    cbam_feature = Conv2D(filters = 1,kernel_size=kernel_size,strides=1,padding='same',activation='sigmoid',kernel_initializer='he_normal',use_bias=False)(concat)	
    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((3, 1, 2))(cbam_feature)
    return multiply([input_feature, cbam_feature])

# %%
from keras.layers import BatchNormalization, add
from keras.layers import Conv2D

kernel_initializer = 'he_uniform'


def conv_block_2D(x, filters, block_type, repeat=1, dilation_rate=1, size=3, padding='same'):
    result = x

    for i in range(0, repeat):

        if block_type == 'separated':
            result = separated_conv2D_block(result, filters, size=size, padding=padding)
        elif block_type == 'duckv2':
            result = duckv2_conv2D_block(result, filters, size=size)
        elif block_type == 'midscope':
            result = midscope_conv2D_block(result, filters)
        elif block_type == 'widescope':
            result = widescope_conv2D_block(result, filters)
        elif block_type == 'resnet':
            result = resnet_conv2D_block(result, filters, dilation_rate)
        elif block_type == 'conv':
            result = Conv2D(filters, (size, size),
                            activation='relu', kernel_initializer=kernel_initializer, padding=padding)(result)
        elif block_type == 'double_convolution':
            result = double_convolution_with_batch_normalization(result, filters, dilation_rate)

        else:
            return None

    return result


def duckv2_conv2D_block(x, filters, size):
    x = BatchNormalization(axis=-1)(x)
    x1 = widescope_conv2D_block(x, filters)

    x2 = midscope_conv2D_block(x, filters)

    x3 = conv_block_2D(x, filters, 'resnet', repeat=1)

    x4 = conv_block_2D(x, filters, 'resnet', repeat=2)

    x5 = conv_block_2D(x, filters, 'resnet', repeat=3)

    x6 = separated_conv2D_block(x, filters, size=6, padding='same')

    x = add([x1, x2, x3, x4, x5, x6])

    x = BatchNormalization(axis=-1)(x)

    return x


def separated_conv2D_block(x, filters, size=3, padding='same'):
    x = Conv2D(filters, (1, size), activation='relu', kernel_initializer=kernel_initializer, padding=padding)(x)

    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters, (size, 1), activation='relu', kernel_initializer=kernel_initializer, padding=padding)(x)

    x = BatchNormalization(axis=-1)(x)

    return x


def midscope_conv2D_block(x, filters):
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=1)(x)

    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=2)(x)

    x = BatchNormalization(axis=-1)(x)

    return x


def widescope_conv2D_block(x, filters):
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=1)(x)

    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=2)(x)

    x = BatchNormalization(axis=-1)(x)

    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=3)(x)

    x = BatchNormalization(axis=-1)(x)

    return x


def resnet_conv2D_block(x, filters, dilation_rate=1):
    x1 = Conv2D(filters, (1, 1), activation='relu', kernel_initializer=kernel_initializer, padding='same',
                dilation_rate=dilation_rate)(x)

    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=dilation_rate)(x)
    x = BatchNormalization(axis=-1)(x)
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=dilation_rate)(x)
    x = BatchNormalization(axis=-1)(x)
    x_final = add([x, x1])

    x_final = BatchNormalization(axis=-1)(x_final)

    return x_final


def double_convolution_with_batch_normalization(x, filters, dilation_rate=1):
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=dilation_rate)(x)
    x = BatchNormalization(axis=-1)(x)
    x = Conv2D(filters, (3, 3), activation='relu', kernel_initializer=kernel_initializer, padding='same',
               dilation_rate=dilation_rate)(x)
    x = BatchNormalization(axis=-1)(x)

    return x

# %%
from tensorflow.keras.layers import Conv2D, UpSampling2D


kernel_initializer = 'he_uniform'
interpolation = "nearest"



def create_model(img_height, img_width, input_chanels, out_classes, starting_filters):
    input_layer = tf.keras.layers.Input((img_height, img_width, input_chanels))

    print('Starting DUCK-Net')

    p1 = Conv2D(starting_filters * 2, 2, strides=2, padding='same')(input_layer)
    p2 = Conv2D(starting_filters * 4, 2, strides=2, padding='same')(p1)
    p3 = Conv2D(starting_filters * 8, 2, strides=2, padding='same')(p2)
    p4 = Conv2D(starting_filters * 16, 2, strides=2, padding='same')(p3)
    p5 = Conv2D(starting_filters * 32, 2, strides=2, padding='same')(p4)

    t0 = conv_block_2D(input_layer, starting_filters, 'duckv2', repeat=1)

    l1i = Conv2D(starting_filters * 2, 2, strides=2, padding='same')(t0)
    l1i = cbam_block(l1i)
    s1 = add([l1i, p1])
    t1 = conv_block_2D(s1, starting_filters * 2, 'duckv2', repeat=1)

    l2i = Conv2D(starting_filters * 4, 2, strides=2, padding='same')(t1)
    l2i = cbam_block(l2i)
    s2 = add([l2i, p2])
    t2 = conv_block_2D(s2, starting_filters * 4, 'duckv2', repeat=1)

    l3i = Conv2D(starting_filters * 8, 2, strides=2, padding='same')(t2)
    l3i = cbam_block(l3i)
    s3 = add([l3i, p3])
    t3 = conv_block_2D(s3, starting_filters * 8, 'duckv2', repeat=1)

    l4i = Conv2D(starting_filters * 16, 2, strides=2, padding='same')(t3)
    l4i = cbam_block(l4i)
    s4 = add([l4i, p4])
    t4 = conv_block_2D(s4, starting_filters * 16, 'duckv2', repeat=1)

    l5i = Conv2D(starting_filters * 32, 2, strides=2, padding='same')(t4)
    l5i = cbam_block(l5i)
    s5 = add([l5i, p5])
    t51 = conv_block_2D(s5, starting_filters * 32, 'resnet', repeat=2)
    t53 = conv_block_2D(t51, starting_filters * 16, 'resnet', repeat=2)
    
    #----------------------------------------------------------------------------------#

    l5o = UpSampling2D((2, 2), interpolation=interpolation)(t53)
    c4 = add([l5o, t4])
    q4 = conv_block_2D(c4, starting_filters * 8, 'duckv2', repeat=1)
    

    l4o = UpSampling2D((2, 2), interpolation=interpolation)(q4)
    c3 = add([l4o, t3])
    q3 = conv_block_2D(c3, starting_filters * 4, 'duckv2', repeat=1)


    l3o = UpSampling2D((2, 2), interpolation=interpolation)(q3)
    c2 = add([l3o, t2])
    q6 = conv_block_2D(c2, starting_filters * 2, 'duckv2', repeat=1)
    #print(q6.shape)
    
    l2o = UpSampling2D((2, 2), interpolation=interpolation)(q6)
    c1 = add([l2o, t1])
    q1 = conv_block_2D(c1, starting_filters, 'duckv2', repeat=1)
    #print(q1.shape)

    l1o = UpSampling2D((2, 2), interpolation=interpolation)(q1)
    c0 = add([l1o, t0])
    z1 = conv_block_2D(c0, starting_filters, 'duckv2', repeat=1)
    #print(z1.shape)

    output = Conv2D(out_classes, (1, 1), activation='sigmoid')(z1)

    model = Model(inputs=input_layer, outputs=output)

    return model

# %%
model = create_model(img_height=256, img_width=256, input_chanels=3, out_classes=1, starting_filters=17)
# Out:
# Starting DUCK-Net

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  batch_normalization_711 (B  (None, 256, 256, 3)          12        ['input_7[0][0]']
#  atchNormalization)
#
#  conv2d_734 (Conv2D)         (None, 256, 256, 17)         476       ['batch_normalization_711[0][0
#                                                                     ]']
#
#  batch_normalization_726 (B  (None, 256, 256, 17)         68        ['conv2d_734[0][0]']
#  atchNormalization)
#
#  conv2d_735 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_726[0][0
#                                                                     ]']
#
#  batch_normalization_727 (B  (None, 256, 256, 17)         68        ['conv2d_735[0][0]']
#  atchNormalization)
#
#  conv2d_733 (Conv2D)         (None, 256, 256, 17)         68        ['batch_normalization_711[0][0
#                                                                     ]']
#
#  add_236 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_727[0][0
#                                                                     ]',
#                                                                      'conv2d_733[0][0]']
#
#  batch_normalization_728 (B  (None, 256, 256, 17)         68        ['add_236[0][0]']
#  atchNormalization)
#
#  conv2d_728 (Conv2D)         (None, 256, 256, 17)         476       ['batch_normalization_711[0][0
#                                                                     ]']
#
#  conv2d_737 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_728[0][0
#                                                                     ]']
#
#  batch_normalization_720 (B  (None, 256, 256, 17)         68        ['conv2d_728[0][0]']
#  atchNormalization)
#
#  batch_normalization_729 (B  (None, 256, 256, 17)         68        ['conv2d_737[0][0]']
#  atchNormalization)
#
#  conv2d_729 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_720[0][0
#                                                                     ]']
#
#  conv2d_738 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_729[0][0
#                                                                     ]']
#
#  batch_normalization_721 (B  (None, 256, 256, 17)         68        ['conv2d_729[0][0]']
#  atchNormalization)
#
#  conv2d_727 (Conv2D)         (None, 256, 256, 17)         68        ['batch_normalization_711[0][0
#                                                                     ]']
#
#  batch_normalization_730 (B  (None, 256, 256, 17)         68        ['conv2d_738[0][0]']
#  atchNormalization)
#
#  conv2d_736 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_728[0][0
#                                                                     ]']
#
#  add_234 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_721[0][0
#                                                                     ]',
#                                                                      'conv2d_727[0][0]']
#
#  add_237 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_730[0][0
#                                                                     ]',
#                                                                      'conv2d_736[0][0]']
#
#  batch_normalization_722 (B  (None, 256, 256, 17)         68        ['add_234[0][0]']
#  atchNormalization)
#
#  batch_normalization_731 (B  (None, 256, 256, 17)         68        ['add_237[0][0]']
#  atchNormalization)
#
#  conv2d_719 (Conv2D)         (None, 256, 256, 17)         476       ['batch_normalization_711[0][0
#                                                                     ]']
#
#  conv2d_725 (Conv2D)         (None, 256, 256, 17)         476       ['batch_normalization_711[0][0
#                                                                     ]']
#
#  conv2d_731 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_722[0][0
#                                                                     ]']
#
#  conv2d_740 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_731[0][0
#                                                                     ]']
#
#  batch_normalization_712 (B  (None, 256, 256, 17)         68        ['conv2d_719[0][0]']
#  atchNormalization)
#
#  batch_normalization_717 (B  (None, 256, 256, 17)         68        ['conv2d_725[0][0]']
#  atchNormalization)
#
#  batch_normalization_723 (B  (None, 256, 256, 17)         68        ['conv2d_731[0][0]']
#  atchNormalization)
#
#  batch_normalization_732 (B  (None, 256, 256, 17)         68        ['conv2d_740[0][0]']
#  atchNormalization)
#
#  conv2d_720 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_712[0][0
#                                                                     ]']
#
#  conv2d_722 (Conv2D)         (None, 256, 256, 17)         476       ['batch_normalization_711[0][0
#                                                                     ]']
#
#  conv2d_726 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_717[0][0
#                                                                     ]']
#
#  conv2d_732 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_723[0][0
#                                                                     ]']
#
#  conv2d_741 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_732[0][0
#                                                                     ]']
#
#  conv2d_742 (Conv2D)         (None, 256, 256, 17)         323       ['batch_normalization_711[0][0
#                                                                     ]']
#
#  batch_normalization_713 (B  (None, 256, 256, 17)         68        ['conv2d_720[0][0]']
#  atchNormalization)
#
#  batch_normalization_715 (B  (None, 256, 256, 17)         68        ['conv2d_722[0][0]']
#  atchNormalization)
#
#  batch_normalization_718 (B  (None, 256, 256, 17)         68        ['conv2d_726[0][0]']
#  atchNormalization)
#
#  conv2d_724 (Conv2D)         (None, 256, 256, 17)         68        ['batch_normalization_711[0][0
#                                                                     ]']
#
#  batch_normalization_724 (B  (None, 256, 256, 17)         68        ['conv2d_732[0][0]']
#  atchNormalization)
#
#  conv2d_730 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_722[0][0
#                                                                     ]']
#
#  batch_normalization_733 (B  (None, 256, 256, 17)         68        ['conv2d_741[0][0]']
#  atchNormalization)
#
#  conv2d_739 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_731[0][0
#                                                                     ]']
#
#  batch_normalization_735 (B  (None, 256, 256, 17)         68        ['conv2d_742[0][0]']
#  atchNormalization)
#
#  conv2d_721 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_713[0][0
#                                                                     ]']
#
#  conv2d_723 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_715[0][0
#                                                                     ]']
#
#  add_233 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_718[0][0
#                                                                     ]',
#                                                                      'conv2d_724[0][0]']
#
#  add_235 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_724[0][0
#                                                                     ]',
#                                                                      'conv2d_730[0][0]']
#
#  add_238 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_733[0][0
#                                                                     ]',
#                                                                      'conv2d_739[0][0]']
#
#  conv2d_743 (Conv2D)         (None, 256, 256, 17)         1751      ['batch_normalization_735[0][0
#                                                                     ]']
#
#  batch_normalization_714 (B  (None, 256, 256, 17)         68        ['conv2d_721[0][0]']
#  atchNormalization)
#
#  batch_normalization_716 (B  (None, 256, 256, 17)         68        ['conv2d_723[0][0]']
#  atchNormalization)
#
#  batch_normalization_719 (B  (None, 256, 256, 17)         68        ['add_233[0][0]']
#  atchNormalization)
#
#  batch_normalization_725 (B  (None, 256, 256, 17)         68        ['add_235[0][0]']
#  atchNormalization)
#
#  batch_normalization_734 (B  (None, 256, 256, 17)         68        ['add_238[0][0]']
#  atchNormalization)
#
#  batch_normalization_736 (B  (None, 256, 256, 17)         68        ['conv2d_743[0][0]']
#  atchNormalization)
#
#  add_239 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_714[0][0
#                                                                     ]',
#                                                                      'batch_normalization_716[0][0
#                                                                     ]',
#                                                                      'batch_normalization_719[0][0
#                                                                     ]',
#                                                                      'batch_normalization_725[0][0
#                                                                     ]',
#                                                                      'batch_normalization_734[0][0
#                                                                     ]',
#                                                                      'batch_normalization_736[0][0
#                                                                     ]']
#
#  batch_normalization_737 (B  (None, 256, 256, 17)         68        ['add_239[0][0]']
#  atchNormalization)
#
#  conv2d_744 (Conv2D)         (None, 128, 128, 34)         2346      ['batch_normalization_737[0][0
#                                                                     ]']
#
#  global_average_pooling2d_2  (None, 34)                   0         ['conv2d_744[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_21 (G  (None, 34)                   0         ['conv2d_744[0][0]']
#  lobalMaxPooling2D)
#
#  reshape_42 (Reshape)        (None, 1, 1, 34)             0         ['global_average_pooling2d_21[
#                                                                     0][0]']
#
#  reshape_43 (Reshape)        (None, 1, 1, 34)             0         ['global_max_pooling2d_21[0][0
#                                                                     ]']
#
#  dense_42 (Dense)            (None, 1, 1, 4)              140       ['reshape_42[0][0]',
#                                                                      'reshape_43[0][0]']
#
#  dense_43 (Dense)            (None, 1, 1, 34)             170       ['dense_42[0][0]',
#                                                                      'dense_42[1][0]']
#
#  add_240 (Add)               (None, 1, 1, 34)             0         ['dense_43[0][0]',
#                                                                      'dense_43[1][0]']
#
#  activation_21 (Activation)  (None, 1, 1, 34)             0         ['add_240[0][0]']
#
#  multiply_42 (Multiply)      (None, 128, 128, 34)         0         ['conv2d_744[0][0]',
#                                                                      'activation_21[0][0]']
#
#  lambda_42 (Lambda)          (None, 128, 128, 1)          0         ['multiply_42[0][0]']
#
#  lambda_43 (Lambda)          (None, 128, 128, 1)          0         ['multiply_42[0][0]']
#
#  concatenate_21 (Concatenat  (None, 128, 128, 2)          0         ['lambda_42[0][0]',
#  e)                                                                  'lambda_43[0][0]']
#
#  conv2d_745 (Conv2D)         (None, 128, 128, 1)          98        ['concatenate_21[0][0]']
#
#  multiply_43 (Multiply)      (None, 128, 128, 34)         0         ['multiply_42[0][0]',
#                                                                      'conv2d_745[0][0]']
#
#  conv2d_714 (Conv2D)         (None, 128, 128, 34)         442       ['input_7[0][0]']
#
#  add_241 (Add)               (None, 128, 128, 34)         0         ['multiply_43[0][0]',
#                                                                      'conv2d_714[0][0]']
#
#  batch_normalization_738 (B  (None, 128, 128, 34)         136       ['add_241[0][0]']
#  atchNormalization)
#
#  conv2d_761 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_738[0][0
#                                                                     ]']
#
#  batch_normalization_753 (B  (None, 128, 128, 34)         136       ['conv2d_761[0][0]']
#  atchNormalization)
#
#  conv2d_762 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_753[0][0
#                                                                     ]']
#
#  batch_normalization_754 (B  (None, 128, 128, 34)         136       ['conv2d_762[0][0]']
#  atchNormalization)
#
#  conv2d_760 (Conv2D)         (None, 128, 128, 34)         1190      ['batch_normalization_738[0][0
#                                                                     ]']
#
#  add_245 (Add)               (None, 128, 128, 34)         0         ['batch_normalization_754[0][0
#                                                                     ]',
#                                                                      'conv2d_760[0][0]']
#
#  batch_normalization_755 (B  (None, 128, 128, 34)         136       ['add_245[0][0]']
#  atchNormalization)
#
#  conv2d_755 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_738[0][0
#                                                                     ]']
#
#  conv2d_764 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_755[0][0
#                                                                     ]']
#
#  batch_normalization_747 (B  (None, 128, 128, 34)         136       ['conv2d_755[0][0]']
#  atchNormalization)
#
#  batch_normalization_756 (B  (None, 128, 128, 34)         136       ['conv2d_764[0][0]']
#  atchNormalization)
#
#  conv2d_756 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_747[0][0
#                                                                     ]']
#
#  conv2d_765 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_756[0][0
#                                                                     ]']
#
#  batch_normalization_748 (B  (None, 128, 128, 34)         136       ['conv2d_756[0][0]']
#  atchNormalization)
#
#  conv2d_754 (Conv2D)         (None, 128, 128, 34)         1190      ['batch_normalization_738[0][0
#                                                                     ]']
#
#  batch_normalization_757 (B  (None, 128, 128, 34)         136       ['conv2d_765[0][0]']
#  atchNormalization)
#
#  conv2d_763 (Conv2D)         (None, 128, 128, 34)         1190      ['batch_normalization_755[0][0
#                                                                     ]']
#
#  add_243 (Add)               (None, 128, 128, 34)         0         ['batch_normalization_748[0][0
#                                                                     ]',
#                                                                      'conv2d_754[0][0]']
#
#  add_246 (Add)               (None, 128, 128, 34)         0         ['batch_normalization_757[0][0
#                                                                     ]',
#                                                                      'conv2d_763[0][0]']
#
#  batch_normalization_749 (B  (None, 128, 128, 34)         136       ['add_243[0][0]']
#  atchNormalization)
#
#  batch_normalization_758 (B  (None, 128, 128, 34)         136       ['add_246[0][0]']
#  atchNormalization)
#
#  conv2d_746 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_738[0][0
#                                                                     ]']
#
#  conv2d_752 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_738[0][0
#                                                                     ]']
#
#  conv2d_758 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_749[0][0
#                                                                     ]']
#
#  conv2d_767 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_758[0][0
#                                                                     ]']
#
#  batch_normalization_739 (B  (None, 128, 128, 34)         136       ['conv2d_746[0][0]']
#  atchNormalization)
#
#  batch_normalization_744 (B  (None, 128, 128, 34)         136       ['conv2d_752[0][0]']
#  atchNormalization)
#
#  batch_normalization_750 (B  (None, 128, 128, 34)         136       ['conv2d_758[0][0]']
#  atchNormalization)
#
#  batch_normalization_759 (B  (None, 128, 128, 34)         136       ['conv2d_767[0][0]']
#  atchNormalization)
#
#  conv2d_747 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_739[0][0
#                                                                     ]']
#
#  conv2d_749 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_738[0][0
#                                                                     ]']
#
#  conv2d_753 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_744[0][0
#                                                                     ]']
#
#  conv2d_759 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_750[0][0
#                                                                     ]']
#
#  conv2d_768 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_759[0][0
#                                                                     ]']
#
#  conv2d_769 (Conv2D)         (None, 128, 128, 34)         6970      ['batch_normalization_738[0][0
#                                                                     ]']
#
#  batch_normalization_740 (B  (None, 128, 128, 34)         136       ['conv2d_747[0][0]']
#  atchNormalization)
#
#  batch_normalization_742 (B  (None, 128, 128, 34)         136       ['conv2d_749[0][0]']
#  atchNormalization)
#
#  batch_normalization_745 (B  (None, 128, 128, 34)         136       ['conv2d_753[0][0]']
#  atchNormalization)
#
#  conv2d_751 (Conv2D)         (None, 128, 128, 34)         1190      ['batch_normalization_738[0][0
#                                                                     ]']
#
#  batch_normalization_751 (B  (None, 128, 128, 34)         136       ['conv2d_759[0][0]']
#  atchNormalization)
#
#  conv2d_757 (Conv2D)         (None, 128, 128, 34)         1190      ['batch_normalization_749[0][0
#                                                                     ]']
#
#  batch_normalization_760 (B  (None, 128, 128, 34)         136       ['conv2d_768[0][0]']
#  atchNormalization)
#
#  conv2d_766 (Conv2D)         (None, 128, 128, 34)         1190      ['batch_normalization_758[0][0
#                                                                     ]']
#
#  batch_normalization_762 (B  (None, 128, 128, 34)         136       ['conv2d_769[0][0]']
#  atchNormalization)
#
#  conv2d_748 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_740[0][0
#                                                                     ]']
#
#  conv2d_750 (Conv2D)         (None, 128, 128, 34)         10438     ['batch_normalization_742[0][0
#                                                                     ]']
#
#  add_242 (Add)               (None, 128, 128, 34)         0         ['batch_normalization_745[0][0
#                                                                     ]',
#                                                                      'conv2d_751[0][0]']
#
#  add_244 (Add)               (None, 128, 128, 34)         0         ['batch_normalization_751[0][0
#                                                                     ]',
#                                                                      'conv2d_757[0][0]']
#
#  add_247 (Add)               (None, 128, 128, 34)         0         ['batch_normalization_760[0][0
#                                                                     ]',
#                                                                      'conv2d_766[0][0]']
#
#  conv2d_770 (Conv2D)         (None, 128, 128, 34)         6970      ['batch_normalization_762[0][0
#                                                                     ]']
#
#  batch_normalization_741 (B  (None, 128, 128, 34)         136       ['conv2d_748[0][0]']
#  atchNormalization)
#
#  batch_normalization_743 (B  (None, 128, 128, 34)         136       ['conv2d_750[0][0]']
#  atchNormalization)
#
#  batch_normalization_746 (B  (None, 128, 128, 34)         136       ['add_242[0][0]']
#  atchNormalization)
#
#  batch_normalization_752 (B  (None, 128, 128, 34)         136       ['add_244[0][0]']
#  atchNormalization)
#
#  batch_normalization_761 (B  (None, 128, 128, 34)         136       ['add_247[0][0]']
#  atchNormalization)
#
#  batch_normalization_763 (B  (None, 128, 128, 34)         136       ['conv2d_770[0][0]']
#  atchNormalization)
#
#  add_248 (Add)               (None, 128, 128, 34)         0         ['batch_normalization_741[0][0
#                                                                     ]',
#                                                                      'batch_normalization_743[0][0
#                                                                     ]',
#                                                                      'batch_normalization_746[0][0
#                                                                     ]',
#                                                                      'batch_normalization_752[0][0
#                                                                     ]',
#                                                                      'batch_normalization_761[0][0
#                                                                     ]',
#                                                                      'batch_normalization_763[0][0
#                                                                     ]']
#
#  batch_normalization_764 (B  (None, 128, 128, 34)         136       ['add_248[0][0]']
#  atchNormalization)
#
#  conv2d_771 (Conv2D)         (None, 64, 64, 68)           9316      ['batch_normalization_764[0][0
#                                                                     ]']
#
#  global_average_pooling2d_2  (None, 68)                   0         ['conv2d_771[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_22 (G  (None, 68)                   0         ['conv2d_771[0][0]']
#  lobalMaxPooling2D)
#
#  reshape_44 (Reshape)        (None, 1, 1, 68)             0         ['global_average_pooling2d_22[
#                                                                     0][0]']
#
#  reshape_45 (Reshape)        (None, 1, 1, 68)             0         ['global_max_pooling2d_22[0][0
#                                                                     ]']
#
#  dense_44 (Dense)            (None, 1, 1, 8)              552       ['reshape_44[0][0]',
#                                                                      'reshape_45[0][0]']
#
#  dense_45 (Dense)            (None, 1, 1, 68)             612       ['dense_44[0][0]',
#                                                                      'dense_44[1][0]']
#
#  add_249 (Add)               (None, 1, 1, 68)             0         ['dense_45[0][0]',
#                                                                      'dense_45[1][0]']
#
#  activation_22 (Activation)  (None, 1, 1, 68)             0         ['add_249[0][0]']
#
#  multiply_44 (Multiply)      (None, 64, 64, 68)           0         ['conv2d_771[0][0]',
#                                                                      'activation_22[0][0]']
#
#  lambda_44 (Lambda)          (None, 64, 64, 1)            0         ['multiply_44[0][0]']
#
#  lambda_45 (Lambda)          (None, 64, 64, 1)            0         ['multiply_44[0][0]']
#
#  concatenate_22 (Concatenat  (None, 64, 64, 2)            0         ['lambda_44[0][0]',
#  e)                                                                  'lambda_45[0][0]']
#
#  conv2d_772 (Conv2D)         (None, 64, 64, 1)            98        ['concatenate_22[0][0]']
#
#  multiply_45 (Multiply)      (None, 64, 64, 68)           0         ['multiply_44[0][0]',
#                                                                      'conv2d_772[0][0]']
#
#  conv2d_715 (Conv2D)         (None, 64, 64, 68)           9316      ['conv2d_714[0][0]']
#
#  add_250 (Add)               (None, 64, 64, 68)           0         ['multiply_45[0][0]',
#                                                                      'conv2d_715[0][0]']
#
#  batch_normalization_765 (B  (None, 64, 64, 68)           272       ['add_250[0][0]']
# ...
#                                                                     ]']
#
#  conv2d_985 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_984[0][0
#                                                                     ]']
#
#  batch_normalization_976 (B  (None, 256, 256, 17)         68        ['conv2d_976[0][0]']
#  atchNormalization)
#
#  conv2d_974 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_966[0][0
#                                                                     ]']
#
#  batch_normalization_985 (B  (None, 256, 256, 17)         68        ['conv2d_985[0][0]']
#  atchNormalization)
#
#  conv2d_983 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_983[0][0
#                                                                     ]']
#
#  add_316 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_976[0][0
#                                                                     ]',
#                                                                      'conv2d_974[0][0]']
#
#  add_319 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_985[0][0
#                                                                     ]',
#                                                                      'conv2d_983[0][0]']
#
#  batch_normalization_977 (B  (None, 256, 256, 17)         68        ['add_316[0][0]']
#  atchNormalization)
#
#  batch_normalization_986 (B  (None, 256, 256, 17)         68        ['add_319[0][0]']
#  atchNormalization)
#
#  conv2d_966 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_966[0][0
#                                                                     ]']
#
#  conv2d_972 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_966[0][0
#                                                                     ]']
#
#  conv2d_978 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_977[0][0
#                                                                     ]']
#
#  conv2d_987 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_986[0][0
#                                                                     ]']
#
#  batch_normalization_967 (B  (None, 256, 256, 17)         68        ['conv2d_966[0][0]']
#  atchNormalization)
#
#  batch_normalization_972 (B  (None, 256, 256, 17)         68        ['conv2d_972[0][0]']
#  atchNormalization)
#
#  batch_normalization_978 (B  (None, 256, 256, 17)         68        ['conv2d_978[0][0]']
#  atchNormalization)
#
#  batch_normalization_987 (B  (None, 256, 256, 17)         68        ['conv2d_987[0][0]']
#  atchNormalization)
#
#  conv2d_967 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_967[0][0
#                                                                     ]']
#
#  conv2d_969 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_966[0][0
#                                                                     ]']
#
#  conv2d_973 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_972[0][0
#                                                                     ]']
#
#  conv2d_979 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_978[0][0
#                                                                     ]']
#
#  conv2d_988 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_987[0][0
#                                                                     ]']
#
#  conv2d_989 (Conv2D)         (None, 256, 256, 17)         1751      ['batch_normalization_966[0][0
#                                                                     ]']
#
#  batch_normalization_968 (B  (None, 256, 256, 17)         68        ['conv2d_967[0][0]']
#  atchNormalization)
#
#  batch_normalization_970 (B  (None, 256, 256, 17)         68        ['conv2d_969[0][0]']
#  atchNormalization)
#
#  batch_normalization_973 (B  (None, 256, 256, 17)         68        ['conv2d_973[0][0]']
#  atchNormalization)
#
#  conv2d_971 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_966[0][0
#                                                                     ]']
#
#  batch_normalization_979 (B  (None, 256, 256, 17)         68        ['conv2d_979[0][0]']
#  atchNormalization)
#
#  conv2d_977 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_977[0][0
#                                                                     ]']
#
#  batch_normalization_988 (B  (None, 256, 256, 17)         68        ['conv2d_988[0][0]']
#  atchNormalization)
#
#  conv2d_986 (Conv2D)         (None, 256, 256, 17)         306       ['batch_normalization_986[0][0
#                                                                     ]']
#
#  batch_normalization_990 (B  (None, 256, 256, 17)         68        ['conv2d_989[0][0]']
#  atchNormalization)
#
#  conv2d_968 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_968[0][0
#                                                                     ]']
#
#  conv2d_970 (Conv2D)         (None, 256, 256, 17)         2618      ['batch_normalization_970[0][0
#                                                                     ]']
#
#  add_315 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_973[0][0
#                                                                     ]',
#                                                                      'conv2d_971[0][0]']
#
#  add_317 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_979[0][0
#                                                                     ]',
#                                                                      'conv2d_977[0][0]']
#
#  add_320 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_988[0][0
#                                                                     ]',
#                                                                      'conv2d_986[0][0]']
#
#  conv2d_990 (Conv2D)         (None, 256, 256, 17)         1751      ['batch_normalization_990[0][0
#                                                                     ]']
#
#  batch_normalization_969 (B  (None, 256, 256, 17)         68        ['conv2d_968[0][0]']
#  atchNormalization)
#
#  batch_normalization_971 (B  (None, 256, 256, 17)         68        ['conv2d_970[0][0]']
#  atchNormalization)
#
#  batch_normalization_974 (B  (None, 256, 256, 17)         68        ['add_315[0][0]']
#  atchNormalization)
#
#  batch_normalization_980 (B  (None, 256, 256, 17)         68        ['add_317[0][0]']
#  atchNormalization)
#
#  batch_normalization_989 (B  (None, 256, 256, 17)         68        ['add_320[0][0]']
#  atchNormalization)
#
#  batch_normalization_991 (B  (None, 256, 256, 17)         68        ['conv2d_990[0][0]']
#  atchNormalization)
#
#  add_321 (Add)               (None, 256, 256, 17)         0         ['batch_normalization_969[0][0
#                                                                     ]',
#                                                                      'batch_normalization_971[0][0
#                                                                     ]',
#                                                                      'batch_normalization_974[0][0
#                                                                     ]',
#                                                                      'batch_normalization_980[0][0
#                                                                     ]',
#                                                                      'batch_normalization_989[0][0
#                                                                     ]',
#                                                                      'batch_normalization_991[0][0
#                                                                     ]']
#
#  batch_normalization_992 (B  (None, 256, 256, 17)         68        ['add_321[0][0]']
#  atchNormalization)
#
#  conv2d_991 (Conv2D)         (None, 256, 256, 1)          18        ['batch_normalization_992[0][0
#                                                                     ]']
#
# ==================================================================================================
# Total params: 39021227 (148.85 MB)
# Trainable params: 38967807 (148.65 MB)
# Non-trainable params: 53420 (208.67 KB)
# __________________________________________________________________________________________________

# %%
import keras.backend as K
import tensorflow as tf


def dice_metric_loss(ground_truth, predictions, smooth=1e-6):
    ground_truth = K.cast(ground_truth, tf.float32)
    predictions = K.cast(predictions, tf.float32)
    ground_truth = K.flatten(ground_truth)
    predictions = K.flatten(predictions)
    intersection = K.sum(predictions * ground_truth)
    union = K.sum(predictions) + K.sum(ground_truth)

    dice = (2. * intersection + smooth) / (union + smooth)

    return 1 - dice

# %%
learning_rate = 1e-4
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss=dice_metric_loss , metrics=['acc'])

# %%
import gc
EPOCHS = 50
min_loss_for_saving = 0.3
step = 0

for epoch in range(0, EPOCHS):
    
    print(f'Training, epoch {epoch}')
    print('Learning Rate: ' + str(learning_rate))

    step += 1
    
    model.fit(x=image_augmented, y=mask_augmented, epochs=1, batch_size=4, validation_data=(x_valid, y_valid), verbose=1 )
    
    prediction_valid = model.predict(x_valid, verbose=0)
    loss_valid = dice_metric_loss(y_valid, prediction_valid)
    
    loss_valid = loss_valid.numpy()
    print("Loss Validation: " + str(loss_valid))
        
    prediction_test = model.predict(x_test, verbose=0)
    loss_test = dice_metric_loss(y_test, prediction_test)
    loss_test = loss_test.numpy()
    print("Loss Test: " + str(loss_test))
     
    if min_loss_for_saving > loss_valid:
        min_loss_for_saving = loss_valid
        print("Saved model with val_loss: ", loss_valid)
        model.save("/kaggle/working/duck-net-multi-head.h5")
        
    #del image_augmented
    #del mask_augmented

    gc.collect()
# Out:
# Training, epoch 0
# Learning Rate: 0.0001
# 122/122 [==============================] - 258s 396ms/step - loss: 0.9076 - acc: 0.6723 - val_loss: 0.7351 - val_acc: 0.9013
# Loss Validation: 0.8629748
# Loss Test: 0.8313628
# Training, epoch 1
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 329ms/step - loss: 0.8617 - acc: 0.8354 - val_loss: 0.6753 - val_acc: 0.9508
# Loss Validation: 0.75239563
# Loss Test: 0.69614995
# Training, epoch 2
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.8372 - acc: 0.8752 - val_loss: 0.6463 - val_acc: 0.9409
# Loss Validation: 0.65207434
# Loss Test: 0.5979215
# Training, epoch 3
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.8179 - acc: 0.8995 - val_loss: 0.6719 - val_acc: 0.9158
# Loss Validation: 0.6538991
# Loss Test: 0.59118664
# Training, epoch 4
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.7971 - acc: 0.9160 - val_loss: 0.6676 - val_acc: 0.9272
# Loss Validation: 0.7609203
# Loss Test: 0.7073033
# Training, epoch 5
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.7785 - acc: 0.9302 - val_loss: 0.6728 - val_acc: 0.9414
# Loss Validation: 0.68131006
# Loss Test: 0.6328072
# Training, epoch 6
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.7553 - acc: 0.9417 - val_loss: 0.6234 - val_acc: 0.9350
# Loss Validation: 0.6183903
# Loss Test: 0.5542718
# Training, epoch 7
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.7308 - acc: 0.9496 - val_loss: 0.6334 - val_acc: 0.9313
# Loss Validation: 0.61241484
# Loss Test: 0.5510442
# Training, epoch 8
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.7040 - acc: 0.9590 - val_loss: 0.5904 - val_acc: 0.9452
# Loss Validation: 0.5453995
# Loss Test: 0.48071772
# Training, epoch 9
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 330ms/step - loss: 0.6799 - acc: 0.9627 - val_loss: 0.5707 - val_acc: 0.9694
# Loss Validation: 0.5239209
# Loss Test: 0.4627295
# Training, epoch 10
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.6557 - acc: 0.9687 - val_loss: 0.4632 - val_acc: 0.9784
# Loss Validation: 0.44411486
# Loss Test: 0.37259024
# Training, epoch 11
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.6203 - acc: 0.9734 - val_loss: 0.4488 - val_acc: 0.9879
# Loss Validation: 0.43001914
# Loss Test: 0.37001854
# Training, epoch 12
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.5884 - acc: 0.9765 - val_loss: 0.4055 - val_acc: 0.9911
# Loss Validation: 0.38394552
# Loss Test: 0.32622755
# Training, epoch 13
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 329ms/step - loss: 0.5592 - acc: 0.9805 - val_loss: 0.3933 - val_acc: 0.9929
# Loss Validation: 0.37318093
# Loss Test: 0.31218433
# Training, epoch 14
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.5197 - acc: 0.9839 - val_loss: 0.5354 - val_acc: 0.9604
# Loss Validation: 0.7203071
# Loss Test: 0.68519115
# Training, epoch 15
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.4826 - acc: 0.9860 - val_loss: 0.3204 - val_acc: 0.9912
# Loss Validation: 0.30569047
# Loss Test: 0.26990348
# Training, epoch 16
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.4629 - acc: 0.9870 - val_loss: 0.3002 - val_acc: 0.9934
# Loss Validation: 0.27821887
# Loss Test: 0.22633445
# Saved model with val_loss:  0.27821887
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Training, epoch 17
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 329ms/step - loss: 0.4261 - acc: 0.9890 - val_loss: 0.2952 - val_acc: 0.9934
# Loss Validation: 0.2654937
# Loss Test: 0.21682984
# Saved model with val_loss:  0.2654937
# Training, epoch 18
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 329ms/step - loss: 0.3983 - acc: 0.9895 - val_loss: 0.2656 - val_acc: 0.9938
# Loss Validation: 0.2392695
# Loss Test: 0.1935072
# Saved model with val_loss:  0.2392695
# Training, epoch 19
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 329ms/step - loss: 0.3577 - acc: 0.9914 - val_loss: 0.2842 - val_acc: 0.9929
# Loss Validation: 0.2515753
# Loss Test: 0.21870631
# Training, epoch 20
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.3362 - acc: 0.9920 - val_loss: 0.2372 - val_acc: 0.9940
# Loss Validation: 0.21382773
# Loss Test: 0.17422646
# Saved model with val_loss:  0.21382773
# Training, epoch 21
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 329ms/step - loss: 0.3159 - acc: 0.9922 - val_loss: 0.2375 - val_acc: 0.9931
# Loss Validation: 0.21365964
# Loss Test: 0.1770922
# Saved model with val_loss:  0.21365964
# Training, epoch 22
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.3054 - acc: 0.9926 - val_loss: 0.2841 - val_acc: 0.9907
# Loss Validation: 0.2593025
# Loss Test: 0.21885777
# Training, epoch 23
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.2673 - acc: 0.9936 - val_loss: 0.2107 - val_acc: 0.9934
# Loss Validation: 0.18176174
# Loss Test: 0.14569253
# Saved model with val_loss:  0.18176174
# Training, epoch 24
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.2589 - acc: 0.9938 - val_loss: 0.2861 - val_acc: 0.9902
# Loss Validation: 0.25634766
# Loss Test: 0.2152847
# Training, epoch 25
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.2408 - acc: 0.9940 - val_loss: 0.1816 - val_acc: 0.9939
# Loss Validation: 0.16424537
# Loss Test: 0.13466173
# Saved model with val_loss:  0.16424537
# Training, epoch 26
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.2311 - acc: 0.9943 - val_loss: 0.2204 - val_acc: 0.9921
# Loss Validation: 0.20358264
# Loss Test: 0.17124856
# Training, epoch 27
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 326ms/step - loss: 0.2320 - acc: 0.9940 - val_loss: 0.2087 - val_acc: 0.9926
# Loss Validation: 0.18748832
# Loss Test: 0.15358442
# Training, epoch 28
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.2138 - acc: 0.9945 - val_loss: 0.1680 - val_acc: 0.9937
# Loss Validation: 0.14239389
# Loss Test: 0.108944476
# Saved model with val_loss:  0.14239389
# Training, epoch 29
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1882 - acc: 0.9949 - val_loss: 0.1750 - val_acc: 0.9931
# Loss Validation: 0.14619082
# Loss Test: 0.121298015
# Training, epoch 30
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1857 - acc: 0.9949 - val_loss: 0.1924 - val_acc: 0.9926
# Loss Validation: 0.16253388
# Loss Test: 0.13502842
# Training, epoch 31
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1853 - acc: 0.9949 - val_loss: 0.1850 - val_acc: 0.9927
# Loss Validation: 0.15742552
# Loss Test: 0.1344226
# Training, epoch 32
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1696 - acc: 0.9951 - val_loss: 0.1793 - val_acc: 0.9928
# Loss Validation: 0.15796852
# Loss Test: 0.14105588
# Training, epoch 33
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1684 - acc: 0.9953 - val_loss: 0.1823 - val_acc: 0.9928
# Loss Validation: 0.16245341
# Loss Test: 0.12599951
# Training, epoch 34
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1517 - acc: 0.9955 - val_loss: 0.1696 - val_acc: 0.9932
# Loss Validation: 0.13912821
# Loss Test: 0.10739726
# Saved model with val_loss:  0.13912821
# Training, epoch 35
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.1674 - acc: 0.9952 - val_loss: 0.2455 - val_acc: 0.9907
# Loss Validation: 0.20653534
# Loss Test: 0.1608662
# Training, epoch 36
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.1607 - acc: 0.9954 - val_loss: 0.2014 - val_acc: 0.9917
# Loss Validation: 0.16885841
# Loss Test: 0.13609886
# Training, epoch 37
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.1521 - acc: 0.9954 - val_loss: 0.1863 - val_acc: 0.9922
# Loss Validation: 0.15172267
# Loss Test: 0.12793517
# Training, epoch 38
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1485 - acc: 0.9956 - val_loss: 0.2032 - val_acc: 0.9917
# Loss Validation: 0.18506145
# Loss Test: 0.1565007
# Training, epoch 39
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1378 - acc: 0.9960 - val_loss: 0.1854 - val_acc: 0.9922
# Loss Validation: 0.15827513
# Loss Test: 0.13752323
# Training, epoch 40
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1408 - acc: 0.9956 - val_loss: 0.1240 - val_acc: 0.9946
# Loss Validation: 0.10327417
# Loss Test: 0.08890194
# Saved model with val_loss:  0.10327417
# Training, epoch 41
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1378 - acc: 0.9958 - val_loss: 0.2305 - val_acc: 0.9905
# Loss Validation: 0.19243991
# Loss Test: 0.16219836
# Training, epoch 42
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1350 - acc: 0.9959 - val_loss: 0.2000 - val_acc: 0.9917
# Loss Validation: 0.16445124
# Loss Test: 0.13342828
# Training, epoch 43
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1283 - acc: 0.9960 - val_loss: 0.1254 - val_acc: 0.9944
# Loss Validation: 0.10346317
# Loss Test: 0.090020895
# Training, epoch 44
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1315 - acc: 0.9959 - val_loss: 0.2245 - val_acc: 0.9906
# Loss Validation: 0.19365191
# Loss Test: 0.15924042
# Training, epoch 45
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1189 - acc: 0.9961 - val_loss: 0.1644 - val_acc: 0.9929
# Loss Validation: 0.13871187
# Loss Test: 0.115246296
# Training, epoch 46
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 328ms/step - loss: 0.1243 - acc: 0.9959 - val_loss: 0.2148 - val_acc: 0.9909
# Loss Validation: 0.16259378
# Loss Test: 0.13637817
# Training, epoch 47
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1177 - acc: 0.9962 - val_loss: 0.2549 - val_acc: 0.9895
# Loss Validation: 0.2055673
# Loss Test: 0.17366701
# Training, epoch 48
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1125 - acc: 0.9964 - val_loss: 0.1780 - val_acc: 0.9923
# Loss Validation: 0.14448625
# Loss Test: 0.12329364
# Training, epoch 49
# Learning Rate: 0.0001
# 122/122 [==============================] - 40s 327ms/step - loss: 0.1211 - acc: 0.9962 - val_loss: 0.2219 - val_acc: 0.9906
# Loss Validation: 0.18092626
# Loss Test: 0.1610552

# %%
from sklearn.metrics import jaccard_score, precision_score, recall_score, accuracy_score, f1_score
print("Loading the model")

model = tf.keras.models.load_model('/kaggle/working/duck-net-multi-head.h5', custom_objects={'dice_metric_loss':dice_metric_loss})

prediction_train = model.predict(x_train, batch_size=4)
prediction_valid = model.predict(x_valid, batch_size=4)
prediction_test = model.predict(x_test, batch_size=4)

print("Predictions done")

dice_train = f1_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                           np.ndarray.flatten(prediction_train > 0.5))
dice_test = f1_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                          np.ndarray.flatten(prediction_test > 0.5))
dice_valid = f1_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                           np.ndarray.flatten(prediction_valid > 0.5))

print("Dice finished")


miou_train = jaccard_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                           np.ndarray.flatten(prediction_train > 0.5))
miou_test = jaccard_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                          np.ndarray.flatten(prediction_test > 0.5))
miou_valid = jaccard_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                           np.ndarray.flatten(prediction_valid > 0.5))

print("Miou finished")


precision_train = precision_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                                  np.ndarray.flatten(prediction_train > 0.5))
precision_test = precision_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                                 np.ndarray.flatten(prediction_test > 0.5))
precision_valid = precision_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                                  np.ndarray.flatten(prediction_valid > 0.5))

print("Precision finished")


recall_train = recall_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                            np.ndarray.flatten(prediction_train > 0.5))
recall_test = recall_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                           np.ndarray.flatten(prediction_test > 0.5))
recall_valid = recall_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                            np.ndarray.flatten(prediction_valid > 0.5))

print("Recall finished")


accuracy_train = accuracy_score(np.ndarray.flatten(np.array(y_train, dtype=bool)),
                                np.ndarray.flatten(prediction_train > 0.5))
accuracy_test = accuracy_score(np.ndarray.flatten(np.array(y_test, dtype=bool)),
                               np.ndarray.flatten(prediction_test > 0.5))
accuracy_valid = accuracy_score(np.ndarray.flatten(np.array(y_valid, dtype=bool)),
                                np.ndarray.flatten(prediction_valid > 0.5))


print("Accuracy finished")
# Out:
# Loading the model
# 122/122 [==============================] - 18s 86ms/step
# 16/16 [==============================] - 8s 88ms/step
# 16/16 [==============================] - 1s 88ms/step
# Predictions done
# Dice finished
# Miou finished
# Precision finished
# Recall finished
# Accuracy finished

# %%
final_file = '/kaggle/working/'+'results_'+'CBAM_DUCK-Net'+ '.txt'
print(final_file)

with open(final_file, 'a') as f:
    f.write('clinic-db' + '\n\n')
    f.write('dice_train: ' + str(dice_train) + ' dice_valid: ' + str(dice_valid) + ' dice_test: ' + str(dice_test) + '\n\n')
    f.write('miou_train: ' + str(miou_train) + ' miou_valid: ' + str(miou_valid) + ' miou_test: ' + str(miou_test) + '\n\n')
    f.write('precision_train: ' + str(precision_train) + ' precision_valid: ' + str(precision_valid) + ' precision_test: ' + str(precision_test) + '\n\n')
    f.write('recall_train: ' + str(recall_train) + ' recall_valid: ' + str(recall_valid) + ' recall_test: ' + str(recall_test) + '\n\n')
    f.write('accuracy_train: ' + str(accuracy_train) + ' accuracy_valid: ' + str(accuracy_valid) + ' accuracy_test: ' + str(accuracy_test) + '\n\n\n\n')

print('File done')
# Out:
# /kaggle/working/results_CBAM_DUCK-Net.txt
# File done
